# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(system("ps -aux", intern = TRUE))
# Out:
# [1] "USER       PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND"
# [2] "jovyan       1  0.0  0.0   4364    64 ?        Ss   Jan28   0:03 tini -- start-notebook.sh"
# [3] "jovyan       5  0.0  5.7 359732 58400 ?        Sl   Jan28   0:24 /opt/conda/bin/python /opt/conda/bin/jupyter-notebook"
# [4] "jovyan      52  0.0  7.0 358692 71408 ?        Ssl  Jan29   0:03 /opt/conda/lib/R/bin/exec/R --slave -e IRkernel::main() --args /home/jovyan/.local/share/jupyter/runtime/kernel-00d871f3-9f3d-4e20-b94b-754514d21d2b.json"
# [5] "jovyan      65  0.0  4.7 252152 48356 ?        Ssl  Jan29   0:00 /opt/conda/lib/R/bin/exec/R --slave -e IRkernel::main() --args /home/jovyan/.local/share/jupyter/runtime/kernel-038f3902-74d9-4d89-94ec-b7c109e82fd6.json"
# [6] "jovyan      78  0.0  5.5 320288 56608 ?        Ssl  01:19   0:00 /opt/conda/lib/R/bin/exec/R --slave -e IRkernel::main() --args /home/jovyan/.local/share/jupyter/runtime/kernel-a64c2811-7d69-49a3-ace3-90de3180282e.json"
# [7] "jovyan      89  0.1  5.3 319812 54584 ?        Ssl  01:22   0:00 /opt/conda/lib/R/bin/exec/R --slave -e IRkernel::main() --args /home/jovyan/.local/share/jupyter/runtime/kernel-2bfedea1-3f0b-4862-9398-7b87305460a5.json"
# [8] "jovyan     100  0.0  0.0   4504   704 ?        S    01:30   0:00 sh -c ps -aux"
# [9] "jovyan     101  0.0  0.3  36084  3144 ?        R    01:30   0:00 ps -aux"

# %% [markdown]
# 3. In a markdown cell, answer: How can this command be interpreted to show how long your system has been running? -Determine the time zone by running timezone command below.
# -Compare the time to the launch time in AWS screenshot.

# %% [markdown]
# Each line shows how long a process has been running as well.

# %%
Sys.timezone (location = TRUE)
# Out:
# [1] "Zulu"

# %% [markdown]
# Zulu time zone is equivalent to GMT, 8 hours ahead of PST. The START column, if converted from GMT to PST shows that the notebook was started at 22:58pmGMT or 2:58pmPST. Compared to the AWS screenshot, the system has been running for 10 minutes.

# %% [markdown]
# 4. In a markdown cell, answer:
# Vector: (2,5,3,6,2,7,4,5,6)
# Length = 9 (number of elements in the vector)
# Magnitude = square root of 204, or ~14.28 (Euclidean distance of the vector)

# %% [markdown]
# 5. Run above vector in R

# %%
length(c(2,5,3,6,2,7,4,5,6))
# Out:
# [1] 9

# %%
sqrt(2^2+5^2+3^2+6^2+2^2+7^2+4^2+5^2+6^2)
# Out:
# [1] 14.28286

# %% [markdown]
# 6. In a R cell: use solve() to prove that the line through (3,4) and (-1,2) is y= .5x+2.5

# %%
x <-rbind(c(1,3),c(1,-1))
y <- c(4,2)
beta <- solve(x,y)
beta
print(x)
# Out:
# [1] 2.5 0.5
#      [,1] [,2]
# [1,]    1    3
# [2,]    1   -1

# %% [markdown]
# Tree command screenshot:

# %% [markdown]
# ```
# ubuntu@ip-172-31-30-50:~/UCLA_Final1$ tree
# .
# ├── data
# │   └── data-file.txt
# ├── ipynb
# │   ├── data description.ipynb
# │   └── Final_exam.ipynb
# └── README.md
#
# 2 directories, 4 files
# ```
