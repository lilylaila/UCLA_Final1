# %%
data <- read.delim("https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data", sep=",", header=FALSE) 
data
# Out:
#      V1 V2    V3    V4    V5     V6     V7     V8     V9
# 1    M  0.455 0.365 0.095 0.5140 0.2245 0.1010 0.150  15
# 2    M  0.350 0.265 0.090 0.2255 0.0995 0.0485 0.070   7
# 3    F  0.530 0.420 0.135 0.6770 0.2565 0.1415 0.210   9
# 4    M  0.440 0.365 0.125 0.5160 0.2155 0.1140 0.155  10
# 5    I  0.330 0.255 0.080 0.2050 0.0895 0.0395 0.055   7
# 6    I  0.425 0.300 0.095 0.3515 0.1410 0.0775 0.120   8
# 7    F  0.530 0.415 0.150 0.7775 0.2370 0.1415 0.330  20
# 8    F  0.545 0.425 0.125 0.7680 0.2940 0.1495 0.260  16
# 9    M  0.475 0.370 0.125 0.5095 0.2165 0.1125 0.165   9
# 10   F  0.550 0.440 0.150 0.8945 0.3145 0.1510 0.320  19
# 11   F  0.525 0.380 0.140 0.6065 0.1940 0.1475 0.210  14
# 12   M  0.430 0.350 0.110 0.4060 0.1675 0.0810 0.135  10
# 13   M  0.490 0.380 0.135 0.5415 0.2175 0.0950 0.190  11
# 14   F  0.535 0.405 0.145 0.6845 0.2725 0.1710 0.205  10
# 15   F  0.470 0.355 0.100 0.4755 0.1675 0.0805 0.185  10
# ...

# %%
length(data)
# Out:
# [1] 9

# %%
nrow(data)
# Out:
# [1] 4177

# %%
class(data)
# Out:
# [1] "data.frame"

# %%
colnames(data) <- c("Sex", "Length", "Diameter", "Height", "WWeight", "SWeight", "VWeight", "SWeight", "Rings")

# %%
summary(data)
# Out:
#  Sex          Length         Diameter          Height          WWeight
#  F:1307   Min.   :0.075   Min.   :0.0550   Min.   :0.0000   Min.   :0.0020
#  I:1342   1st Qu.:0.450   1st Qu.:0.3500   1st Qu.:0.1150   1st Qu.:0.4415
#  M:1528   Median :0.545   Median :0.4250   Median :0.1400   Median :0.7995
#           Mean   :0.524   Mean   :0.4079   Mean   :0.1395   Mean   :0.8287
#           3rd Qu.:0.615   3rd Qu.:0.4800   3rd Qu.:0.1650   3rd Qu.:1.1530
#           Max.   :0.815   Max.   :0.6500   Max.   :1.1300   Max.   :2.8255
#     SWeight          VWeight          SWeight           Rings
#  Min.   :0.0010   Min.   :0.0005   Min.   :0.0015   Min.   : 1.000
#  1st Qu.:0.1860   1st Qu.:0.0935   1st Qu.:0.1300   1st Qu.: 8.000
#  Median :0.3360   Median :0.1710   Median :0.2340   Median : 9.000
#  Mean   :0.3594   Mean   :0.1806   Mean   :0.2388   Mean   : 9.934
#  3rd Qu.:0.5020   3rd Qu.:0.2530   3rd Qu.:0.3290   3rd Qu.:11.000
# ...

# %%
str(data)
# Out:
# 'data.frame':	4177 obs. of  9 variables:
#  $ Sex     : Factor w/ 3 levels "F","I","M": 3 3 1 3 2 2 1 1 3 1 ...
#  $ Length  : num  0.455 0.35 0.53 0.44 0.33 0.425 0.53 0.545 0.475 0.55 ...
#  $ Diameter: num  0.365 0.265 0.42 0.365 0.255 0.3 0.415 0.425 0.37 0.44 ...
#  $ Height  : num  0.095 0.09 0.135 0.125 0.08 0.095 0.15 0.125 0.125 0.15 ...
#  $ WWeight : num  0.514 0.226 0.677 0.516 0.205 ...
#  $ SWeight : num  0.2245 0.0995 0.2565 0.2155 0.0895 ...
#  $ VWeight : num  0.101 0.0485 0.1415 0.114 0.0395 ...
#  $ SWeight : num  0.15 0.07 0.21 0.155 0.055 0.12 0.33 0.26 0.165 0.32 ...
#  $ Rings   : int  15 7 9 10 7 8 20 16 9 19 ...

# %% [markdown]
# Sample of data exploration below. The two plots shows relationship (or correlation) between length and rings (first plot) and whole weight and rings (second plot). Further data exploration is needed.

# %%
plot(data$Length, data$Rings)
# Out:
# plot without title

# %%
plot(data$WWeight, data$Rings)
# Out:
# plot without title
